# %%
## Load Dependencies
from __future__ import absolute_import
from __future__ import print_function
from __future__ import division

#import json, os, re, shutil, sys, time
import os, shutil, time
#from importlib import reload
from imp import reload
#import collections, itertools
import unittest
#from trainer import unittest
#from . import unittest
#import trainer.unittest as unittest
#from IPython.display import display, HTML

# NLTK for NLP utils and corpora
#import nltk

# NumPy and TensorFlow
import numpy as np
import tensorflow as tf
assert(tf.__version__.startswith("1."))

# Helper libraries
from trainer import utils#, vocabulary, tf_embed_viz
#import utils
#import trainer.utils as utils

# rnnlm code
from trainer import rnnlm
#import trainer.rnnlm as rnnlm
#import rnnlm
reload(rnnlm)
#from trainer import rnnlm_test
#import trainer.rnnlm_test as rnnlm_test
#reload(rnnlm_test)
#from . import rnnlm; reload(rnnlm)
#from . import rnnlm_test; reload(rnnlm_test)
#import rnnlm; reload(rnnlm)
#import rnnlm_test; reload(rnnlm_test)
# packages for extracting data
import pandas as pd

#
#import cloudstorage as gcs
import random
import csv

# %%
def make_tensorboard(tf_graphdir="/tmp/artificial_hotel_reviews/a4_graph", V=100, H=1024, num_layers=2):
    reload(rnnlm)
    TF_GRAPHDIR = tf_graphdir
    # Clear old log directory.
    shutil.rmtree(TF_GRAPHDIR, ignore_errors=True)
    
    lm = rnnlm.RNNLM(V=V, H=H, num_layers=num_layers)
    lm.BuildCoreGraph()
    lm.BuildTrainGraph()
    lm.BuildSamplerGraph()
    summary_writer = tf.summary.FileWriter(TF_GRAPHDIR, lm.graph)
    return summary_writer

# Unit Tests
def test_graph():
    reload(rnnlm); reload(rnnlm_test)
    utils.run_tests(rnnlm_test, ["TestRNNLMCore", "TestRNNLMTrain", "TestRNNLMSampler"])

def test_training():
    reload(rnnlm); reload(rnnlm_test)
    th = rnnlm_test.RunEpochTester("test_toy_model")
    th.setUp(); th.injectCode(run_epoch, score_dataset)
    unittest.TextTestRunner(verbosity=2).run(th)

# %%
def score_each_step(lm, session, ids):
    #no batching
    bi = utils.rnnlm_batch_generator(ids, batch_size=100, max_time=100)
    for i, (w,y) in enumerate(bi):
        if i == 0:
            h = session.run(lm.initial_h_, {lm.input_w_: w})
        feed_dict = {lm.input_w_:w,
                     lm.target_y_:y,
                     lm.learning_rate_: 0.002,
                     lm.use_dropout_: False,
                     lm.initial_h_:h}
        cost, h, _ = session.run([loss, lm.final_h_, train_op],feed_dict=feed_dict)
        #pick up here

# %%
## Training Functions
def run_epoch(lm, session, batch_iterator,
              train=False, verbose=False,
              tick_s=5, learning_rate=None):
    assert(learning_rate is not None)
    start_time = time.time()
    tick_time = start_time  # for showing status
    total_cost = 0.0  # total cost, summed over all words
    total_batches = 0
    total_words = 0

    if train:
        train_op = lm.train_step0_
        use_dropout = True
        loss = lm.train_loss_
    else:
        train_op = tf.no_op()
        use_dropout = False  # no dropout at test time
        loss = lm.loss_  # true loss, if train_loss is an approximation

    for i, (w, y) in enumerate(batch_iterator):
        cost = 0.0
        # At first batch in epoch, get a clean intitial state.
        if i == 0:
            h = session.run(lm.initial_h_, {lm.input_w_: w})

        #### YOUR CODE HERE ####
        feed_dict = {lm.input_w_:w,
                     lm.target_y_:y,
                     lm.learning_rate_: learning_rate,
                     lm.use_dropout_: use_dropout,
                     lm.initial_h_:h}
        cost, h, _ = session.run([loss, lm.final_h_, train_op],feed_dict=feed_dict)

        #### END(YOUR CODE) ####
        total_cost += cost
        total_batches = i + 1
        total_words += w.size  # w.size = batch_size * max_time

        ##
        # Print average loss-so-far for epoch
        # If using train_loss_, this may be an underestimate.
        if verbose and (time.time() - tick_time >= tick_s):
            avg_cost = total_cost / total_batches
            avg_wps = total_words / (time.time() - start_time)
            print("[batch {:d}]: seen {:d} words at {:.1f} wps, loss = {:.3f}".format(
                i, total_words, avg_wps, avg_cost))
            tick_time = time.time()  # reset time ticker

    return total_cost / total_batches

# %%
def run_gan_epoch(lm, session, words_to_ids, ids_to_words, train_list, batch_size, verbose=False, tick_s=10, learning_rate=None):
    assert(learning_rate is not None)
    start_time = time.time()
    tick_time = start_time  # for showing status
    total_cost = 0.0  # total cost, summed over all words
    total_batches = 0
    total_words = 0
    train_op = lm.train_step_
    loss = lm.loss_cnn

    #if train:
        #train_op = lm.train_step_
        #use_dropout = True
        ##loss = lm.train_loss_
        #loss = lm.loss_cnn
    #else:
        #train_op = tf.no_op()
        #use_dropout = False  # no dropout at test time
        #loss = lm.loss_  # true loss, if train_loss is an approximation
        #loss = lm.loss_cnn

    ### UPDATED!!! MUST PASS IN TRAIN_IDS as a list of lists, batch_size
    num_samples = 2*batch_size
    total_reviews = len(train_list)
    num_batches_per_epoch = int((total_reviews-1)/batch_size) + 1
    for batch in range(num_batches_per_epoch):
        print("gan batch: ", batch)
        start_index = batch*batch_size
        end_index = min((batch+1) * batch_size, total_reviews)
        current_training_batch = train_list[start_index:end_index]
        #min_review_length = min(len(review) for review in current_training_batch)
        min_review_length = 300 #based on the selection criteria when extracting data.  limits learning to ~60 word context
        #average_review_length = sum([len(review) for review in current_training_batch])/len(current_training_batch)
        #max_steps = 2.0*average_review_length
        max_steps = 325
        
        #for training_review in current_training_batch:
        w = np.repeat([[words_to_ids.get('<SOR>')]], num_samples, axis=0)#MUST PASS IN WORDS_TO_IDS
        h = session.run(lm.initial_h_, {lm.input_w_: w})
        #print(h[0])
        #print(h[0][0].shape)
        #print(h[0][1].shape)
        #can gather all outputs from this loop if you get to it
        #get the cell state and timestep 300
        h_artificial_300 = None
        for i in range(max_steps):
            if i == min_review_length:
                h_artificial_300 = h[0][1]
            h, y = sample_step(lm, session, w[:,-1:], h)
            w = np.hstack((w,y))
        artificial_review_final_states = []
        artificial_review_ids = []
        #for row in w:
        for a, row in enumerate(h_artificial_300):
            #print("generated during training", end=":  ")
            new_artificial_review = []
            for b, word_id in enumerate(w[a]):
                new_artificial_review.append(word_id)
                #print(ids_to_words[word_id], end="")
                if (b != 0) and (word_id == words_to_ids.get("<EOR>")):
                    break
            #print("")
            #if len(new_artificial_review) >= 0.75*average_review_length:
            if len(new_artificial_review) >= min_review_length:
                artificial_review_ids.append(new_artificial_review)
                artificial_review_final_states.append(row)
        
        print("generated during training batch ", batch, ":")
        for review in artificial_review_ids[:5]:
            for word_id in review:
                print(ids_to_words[word_id], end="")
            print()
        #print(artificial_review_ids[:5])
        #now you have current_training_batch and artificial_review_ids
        #clip all data to the same length for simplicity
        num_reviews = min(len(current_training_batch), len(artificial_review_ids))
        print("gan batch: ", batch, " has ", num_reviews, 
              " real reviews and ", num_reviews, " artificial reviews.")
        
        if num_reviews == 0:
            continue
        
        current_training_batch = [review[:min_review_length] for review in current_training_batch]
        #not sure this is needed
        artificial_review_ids = [review[:min_review_length] for review in artificial_review_ids]
        
        ##get final states for real reviews
        #w_training = np.array(current_training_batch)
        #h = session.run(lm.initial_h_, {lm.input_w_: w_training})
        #feed_dict = {lm.input_w_:w_training,
                     #lm.learning_rate_: learning_rate,
                     #lm.use_dropout_: False,
                     #lm.initial_h_:h}
        #h_real = session.run([lm.final_h_],feed_dict=feed_dict)#no training, just get states
        
        #real_review_final_states = []
        #prob don't need to do anything to h_real
        #for row in h_real:
            #if len(new_artificial_review) >= 300:
                #artificial_review_ids.append(new_artificial_review)
                #artificial_review_final_states.append(row)
                
        #now let's even out the number of examples
        current_training_batch = current_training_batch[:num_reviews]
        artificial_review_ids = artificial_review_ids[:num_reviews]
        #print(h_real[0])
        ##print(h_real[1])#wtf why won't this work
        ##print(h_real[1].shape)
        ##h_real = h_real[1][:num_reviews]
        #h_real = h_real[:num_reviews]
        #print(h_real)
        #artificial_review_final_states[:num_reviews]
        real_review_list_for_retraining_softmax = current_training_batch[:]
        
        #label each review and shuffle data
        current_training_batch = [(review,[1,0]) for review in current_training_batch]#might need to swap labels
        artificial_review_training_batch = [(np.array(review),[0,1]) for review in artificial_review_ids]
        #print(current_training_batch[:10])
        #print()
        #print(artificial_review_ids[:10])
        #print()
        ##label each review hidden state and shuffle
        #training_states = [(review,np.array([0,1])) for review in h_real]#might need to swap labels
        #artificial_review_states = [(review,np.array([1,0])) for review in artificial_review_final_states]
        
        #combine training lists
        current_training_batch.extend(artificial_review_training_batch)
        np.random.shuffle(current_training_batch)
        
        #print(current_training_batch[:10])
        #print()
        #np.random.shuffle(training_states)
        #print(training_states)
        
        #train discriminator
        #now unzip into "w" and "y"
        review_list, labels = zip(*current_training_batch)
        #review_states, labels = zip(*training_states)
        #convert to matrix form
        #print(labels)
        w = np.array(list(review_list))
        #w = np.array(list(review_states))
        #y = np.array(list(labels))
        y = np.array(labels)
        #print(w.shape)
        #print(y.shape)
        #print()
        #batching is done at the review level
        #the whole review is fed in at once, so initialize h first
        #if batch == 0:
        
        #train CNN classifier
        train_op = lm.train_step_
        h = session.run(lm.initial_h_, {lm.input_w_: w})
        #feed_dict = {lm.input_x:w,
                     #lm.input_y:y,
                     #lm.learning_rate_: learning_rate,
                     #lm.use_dropout_: True}
        feed_dict = {lm.input_w_: w, 
                     lm.input_y: y,
                     lm.learning_rate_: learning_rate,
                     lm.use_dropout_: True, 
                     lm.initial_h_: h}
        accuracy, cost, h, _ = session.run([lm.accuracy, loss, lm.final_h_, train_op],feed_dict=feed_dict)
        print("discriminator training accuracy for gan batch ", batch, " is: ", accuracy)
        print("discriminator training cost for gan batch ", batch, " is: ", cost)
        
        ##train discriminator on fake reviews
        ##now unzip into "w" and "y"
        #review_list, labels = zip(*artificial_review_ids)
        #w = np.array(list(review_list))
        #y = np.array(labels)
        
        ##train CNN classifier
        #train_op = self.train_step_
        #h = session.run(lm.initial_h_, {lm.input_w_: w})
        #feed_dict = {lm.input_w_: w, 
                     #lm.input_y: y,
                     #lm.learning_rate_: learning_rate,
                     #lm.use_dropout_: True, 
                     #lm.initial_h_: h}
        #accuracy, cost, h, _ = session.run([lm.accuracy, loss, lm.final_h_, train_op],feed_dict=feed_dict)
        #print("fake review accuracy for gan batch ", batch, " is: ", accuracy)
        #print("fake review cost for gan batch ", batch, " is: ", cost)
        
        #train generator
        #relabel fake reviews as real
        artificial_review_training_batch = [(np.array(review),[1,0]) for review in artificial_review_ids]
        #now unzip into "w" and "y"
        review_list, labels = zip(*artificial_review_training_batch)
        w = np.array(list(review_list))
        y = np.array(labels)
        
        #train CNN classifier
        train_op = lm.train_step1_
        h = session.run(lm.initial_h_, {lm.input_w_: w})
        #feed_dict = {lm.input_x:w,
                     #lm.input_y:y,
                     #lm.learning_rate_: learning_rate,
                     #lm.use_dropout_: True}
        feed_dict = {lm.input_w_: w, 
                     lm.input_y: y,
                     lm.learning_rate_: learning_rate,
                     lm.use_dropout_: True, 
                     lm.initial_h_: h}
        accuracy, cost, h, _ = session.run([lm.accuracy, loss, lm.final_h_, train_op],feed_dict=feed_dict)
        print("generator training accuracy for gan batch ", batch, " is: ", accuracy)
        print("generator training cost for gan batch ", batch, " is: ", cost)
        
        ##retrain softmax of rnn on real reviews
        #flattened_real_ids = np.array([item for sublist in real_review_list_for_retraining_softmax for item in sublist])
        ##print(flattened_real_ids[:10])
        ##print(flattened_real_ids.shape)
        ##print()
        #bi = utils.rnnlm_batch_generator(flattened_real_ids, batch_size, max_time=150)
        #for i, (w, y) in enumerate(bi):
            #cost = 0.0
            #if i == 0:
                #h = session.run(lm.initial_h_, {lm.input_w_: w})
            #feed_dict = {lm.input_w_: w, 
                         #lm.target_y_: y, 
                         #lm.learning_rate_: learning_rate,
                         #lm.use_dropout_: False,
                         #lm.initial_h_:h}
            #cost, h, _ = session.run([lm.train_loss_, lm.final_h_, lm.train_step_softmax_],feed_dict=feed_dict)
            #print("softmax re-training cost for gan batch ", batch, " is: ", cost)
    
    ### UPDATED!!!
    total_cost += cost#update
    total_batches = batch + 1
    total_words += w.size  # w.size = batch_size * max_time

    ##
    # Print average loss-so-far for epoch
    # If using train_loss_, this may be an underestimate.
    if verbose and (time.time() - tick_time >= tick_s):
        avg_cost = total_cost / total_batches
        avg_wps = total_words / (time.time() - start_time)
        print("[batch {:d}]: seen {:d} words at {:.1f} wps, loss = {:.3f}".format(
            batch, total_words, avg_wps, avg_cost))
        tick_time = time.time()  # reset time ticker

    return total_cost / total_batches

# %%
def score_dataset(lm, session, ids, name="Data"):
    # For scoring, we can use larger batches to speed things up.
    bi = utils.rnnlm_batch_generator(ids, batch_size=100, max_time=100)
    cost = run_epoch(lm, session, bi, 
                     learning_rate=0.0, train=False, 
                     verbose=False, tick_s=3600)
    print("{:s}: avg. loss: {:.03f}  (perplexity: {:.02f})".format(name, cost, np.exp(cost)))
    return cost


#build a list of list of characters from the 5-star reviews
def preprocess_review_series(review_series):
    review_list = []
    for new_review in review_series:
        clipped_review = new_review[2:-1]
        char_list = list(clipped_review.lower())
        semifinal_review = []
        last_char = ''
        for ascii_char in char_list:
            if ascii_char == '\\' or last_char == '\\':
                pass
            else:
                semifinal_review.append(ascii_char)
            last_char = ascii_char
        if len(semifinal_review) > 300:
            final_review = ['<SOR>'] + semifinal_review + ['<EOR>']
            #print(final_review)
            review_list.append(final_review)
    return review_list

def get_review_series(review_path = '/home/kalvin_kao/yelp_challenge_dataset/review.csv'):
    #review_path = '/home/kalvin_kao/yelp_challenge_dataset/review.csv'
    review_df = pd.read_csv(review_path)
    five_star_review_df = review_df[review_df['stars']==5]
    #five_star_review_series = five_star_review_df['text']
    return five_star_review_df['text']

def get_business_list(business_path = '/home/kalvin_kao/yelp_challenge_dataset/business.csv'):
    #business_path = '/home/kalvin_kao/yelp_challenge_dataset/business.csv'
    return pd.read_csv(business_path)

def split_train_test(review_list, training_samples, test_samples):
    #pass in randomized review list
    train_len = int(np.floor(0.8*len(review_list)))
    test_len = int(np.floor(0.2*len(review_list)))
    training_review_list = review_list[:train_len]
    testing_review_list = review_list[-test_len:]
    randomized_training_list = random.sample(training_review_list, training_samples)
    randomized_testing_list = random.sample(testing_review_list, test_samples)
    training_review_list = [item for sublist in randomized_training_list for item in sublist]
    print("number of training characters", len(training_review_list))
    test_review_list = [item for sublist in randomized_testing_list for item in sublist]
    print("number of test characters", len(test_review_list))
    return randomized_training_list, randomized_testing_list

def make_train_test_data(five_star_review_series, training_samples=20000, test_samples=1000):
    #fix randomization to prevent evaluation on trained samples
    review_list = preprocess_review_series(five_star_review_series)
    #split and shuffle the data
    train_len = int(np.floor(0.8*len(review_list)))
    test_len = int(np.floor(0.2*len(review_list)))
    np.random.shuffle(review_list)
    training_review_list = review_list[:train_len]
    testing_review_list = review_list[-test_len:]
    randomized_training_list = random.sample(training_review_list, training_samples)
    randomized_testing_list = random.sample(testing_review_list, test_samples)
    #training_review_list = [item for sublist in review_list[:training_samples] for item in sublist]
    training_review_list = [item for sublist in randomized_training_list for item in sublist]
    print("number of training characters", len(training_review_list))
    
    #test_review_list = [item for sublist in review_list[training_samples:training_samples+test_samples] for item in sublist]
    test_review_list = [item for sublist in randomized_testing_list for item in sublist]
    print("number of test characters", len(test_review_list))
    return training_review_list, test_review_list


#def make_vocabulary(training_review_list, test_review_list):
#    unique_characters = list(set(training_review_list + test_review_list))
#    #vocabulary
#    char_dict = {w:i for i, w in enumerate(unique_characters)}
#    ids_to_words = {v: k for k, v in char_dict.items()}
#    return char_dict, ids_to_words
def make_vocabulary(dataset_list):
    unique_characters = list(set().union(*dataset_list))
    #unique_characters = list(set(training_review_list + test_review_list))
    #vocabulary
    char_dict = {w:i for i, w in enumerate(unique_characters)}
    ids_to_words = {v: k for k, v in char_dict.items()}
    return char_dict, ids_to_words

def convert_to_ids(char_dict, review_list):
    #convert to flat (1D) np.array(int) of ids
    review_ids = [char_dict.get(token) for token in review_list]
    return np.array(review_ids)

def run_training(train_list, test_ids, words_to_ids, ids_to_words, tf_savedir, model_params, max_time=100, batch_size=256, learning_rate=0.002, num_epochs=20):
    #V = len(words_to_ids.keys())
    # Training parameters
    ## add parameter sets for each attack/defense configuration
    #max_time = 25
    #batch_size = 100
    #learning_rate = 0.01
    #num_epochs = 10
    
    # Model parameters
    #model_params = dict(V=vocab.size, 
                        #H=200, 
                        #softmax_ns=200,
                        #num_layers=2)
    #model_params = dict(V=len(words_to_ids.keys()), 
                        #H=1024, 
                        #softmax_ns=len(words_to_ids.keys()),
                        #num_layers=2)
    #model_params = dict(V=V, H=H, softmax_ns=softmax_ns, num_layers=num_layers)
    
    #TF_SAVEDIR = "/tmp/artificial_hotel_reviews/a4_model"
    TF_SAVEDIR = tf_savedir
    checkpoint_filename = os.path.join(TF_SAVEDIR, "gan")
    trained_filename = os.path.join(TF_SAVEDIR, "gan_trained")
    
    # Will print status every this many seconds
    #print_interval = 5
    print_interval = 30
    
    lm = rnnlm.RNNLM(**model_params)
    lm.BuildCoreGraph()
    lm.BuildTrainGraph()
    ### UPDATED!!!
    lm.BuildSamplerGraph()
    #num_pretrain = 2000
    num_pretrain = 200#low number for testing
    #pretrain on a different set of training data each time
    #train and test ids 
    #pre_train_ids =
    #train_ids = 
    ### UPDATED!!!
    
    # Explicitly add global initializer and variable saver to LM graph
    with lm.graph.as_default():
        initializer = tf.global_variables_initializer()
        saver = tf.train.Saver()
        
    # Clear old log directory
    shutil.rmtree(TF_SAVEDIR, ignore_errors=True)
    if not os.path.isdir(TF_SAVEDIR):
        os.makedirs(TF_SAVEDIR)
    
    with tf.Session(graph=lm.graph) as session:
        # Seed RNG for repeatability
        #tf.set_random_seed(42)
    
        session.run(initializer)
        
        #check trainable variables
        #variables_names = [v.name for v in tf.trainable_variables()]
        #values = session.run(variables_names)
        #for k, v in zip(variables_names, values):
            #print("Variable: ", k)
            #print("Shape: ", v.shape)
            #print(v)
    
        for epoch in range(1,num_epochs+1):
            t0_epoch = time.time()
            np.random.shuffle(train_list)
            #shuffled_train_list = np.random.shuffle(train_list)
            #pre_train_ids = [item for sublist in shuffled_train_list[:num_pretrain] for item in sublist]
            #gan_train_list = shuffled_train_list[num_pretrain:]
            #train_list = 
            pre_train_ids = np.array([item for sublist in train_list[:num_pretrain] for item in sublist])
            #print(pre_train_ids.shape)
            #pre_train_ids = np.array(pre_train_ids)
            gan_train_list = train_list[num_pretrain:]
            if num_pretrain > 0:
                bi = utils.rnnlm_batch_generator(pre_train_ids, batch_size, max_time)
                print("[epoch {:d}] Starting epoch {:d}".format(epoch, epoch))
                # Run a pretraining epoch.
                run_epoch(lm, session, batch_iterator=bi, train=True, verbose=True, tick_s=10, learning_rate=learning_rate)

                print("[epoch {:d}] Completed in {:s}".format(epoch, utils.pretty_timedelta(since=t0_epoch)))
        
            #now train gan
            #run_gan_epoch(lm, session, words_to_ids, ids_to_words, train_list, verbose=False, tick_s=10, learning_rate=None)
            run_gan_epoch(lm, session, words_to_ids, ids_to_words, gan_train_list, batch_size, 
                          verbose=True, tick_s=10, learning_rate=learning_rate)
        
            # Save a checkpoint
            saver.save(session, checkpoint_filename, global_step=epoch)
        
            ##
            # score_dataset will run a forward pass over the entire dataset
            # and report perplexity scores. This can be slow (around 1/2 to 
            # 1/4 as long as a full epoch), so you may want to comment it out
            # to speed up training on a slow machine. Be sure to run it at the 
            # end to evaluate your score.
            print("[epoch {:d}]".format(epoch), end=" ")
            score_dataset(lm, session, pre_train_ids, name="Train set")
            print("[epoch {:d}]".format(epoch), end=" ")
            score_dataset(lm, session, test_ids, name="Test set")
            print("")
        
        # Save final model
        saver.save(session, trained_filename)
        return trained_filename

def get_char_probs(trained_filename, model_params, test_ids):
    lm = rnnlm.RNNLM(**model_params)
    lm.BuildCoreGraph()
    all_review_likelihoods = []
    train_op = tf.no_op()
    use_dropout = False
    loss = lm.loss_
    
    with lm.graph.as_default():
        saver = tf.train.Saver()
    
    with tf.Session(graph=lm.graph) as session:
        #train_op = tf.no_op()
        #use_dropout = False
        #loss = lm.loss_
        
        saver.restore(session, trained_filename)
        
        for review in test_ids:
            review_likelihoods = []
            inputs = review[:-1]
            labels = review[1:]
            inputs_labels = zip(inputs,labels)
            for i, (w,y) in enumerate(inputs_labels):
                
                w = np.array(w)
                y = np.array(y)
                w = w.reshape([1,1])
                y = y.reshape([1,1])
                
                if i == 0:
                    h = session.run(lm.initial_h_, {lm.input_w_: w})

                feed_dict = {lm.input_w_:w, 
                             lm.target_y_:y,
                             lm.learning_rate_: 0.002,
                             lm.use_dropout_: use_dropout,
                             lm.initial_h_:h}
                cost, h = session.run([loss, lm.final_h_],feed_dict=feed_dict)
                likelihood = 2**(-1*cost)
                review_likelihoods.append(likelihood)
            all_review_likelihoods.append(review_likelihoods)
    return all_review_likelihoods

## Sampling
def sample_step(lm, session, input_w, initial_h):
    """Run a single RNN step and return sampled predictions.
  
    Args:
      lm : rnnlm.RNNLM
      session: tf.Session
      input_w : [batch_size] vector of indices
      initial_h : [batch_size, hidden_dims] initial state
    
    Returns:
      final_h : final hidden state, compatible with initial_h
      samples : [batch_size, 1] vector of indices
    """
    # Reshape input to column vector
    input_w = np.array(input_w, dtype=np.int32).reshape([-1,1])

    # Run sample ops
    feed_dict = {lm.input_w_:input_w, lm.initial_h_:initial_h}
    final_h, samples = session.run([lm.final_h_, lm.pred_samples_], feed_dict=feed_dict)

    # Note indexing here: 
    #   [batch_size, max_time, 1] -> [batch_size, 1]
    return final_h, samples[:,-1,:]

def generate_text(trained_filename, model_params, words_to_ids, ids_to_words):
    # Same as above, but as a batch
    #max_steps = 20
    max_steps = 300
    #num_samples = 40000
    num_samples = 40
    random_seed = 42
    
    lm = rnnlm.RNNLM(**model_params)
    lm.BuildCoreGraph()
    lm.BuildSamplerGraph()
    
    with lm.graph.as_default():
        saver = tf.train.Saver()
    
    with tf.Session(graph=lm.graph) as session:
        # Seed RNG for repeatability
        #tf.set_random_seed(random_seed)
        
        # Load the trained model
        saver.restore(session, trained_filename)
    
        # Make initial state for a batch with batch_size = num_samples
        #w = np.repeat([[vocab.START_ID]], num_samples, axis=0)
        w = np.repeat([[words_to_ids.get('<SOR>')]], num_samples, axis=0)
        h = session.run(lm.initial_h_, {lm.input_w_: w})
        # take one step for each sequence on each iteration 
        for i in range(max_steps):
            h, y = sample_step(lm, session, w[:,-1:], h)
            w = np.hstack((w,y))
    
        # Print generated sentences
        for row in w:
            print(trained_filename, end=":  ")
            for i, word_id in enumerate(row):
                #print(vocab.id_to_word[word_id], end=" ")
                print(ids_to_words[word_id], end="")
                #if (i != 0) and (word_id == vocab.START_ID):
                if (i != 0) and (word_id == words_to_ids.get("<EOR>")):
                    break
            print("")

def train_attack_model(training_samples=20000, test_samples=1000, review_path = '/home/kalvin_kao/yelp_challenge_dataset/review.csv'):
    #training_samples=20000
    #test_samples=1000
    #review_path = '/home/kalvin_kao/yelp_challenge_dataset/review.csv'
    start_format = time.time()
    five_star_reviews = get_review_series(review_path)
    train_review_list, test_review_list = make_train_test_data(five_star_reviews, training_samples, test_samples)
    words_to_ids, ids_to_words = make_vocabulary(train_review_list, test_review_list)
    train_ids = convert_to_ids(words_to_ids, train_review_list)
    test_ids = convert_to_ids(words_to_ids, test_review_list)
    end_format = time.time()
    print("data formatting took " + str(end_format-start_format) + " seconds")
    model_params = dict(V=len(words_to_ids.keys()), 
                            H=1024, 
                            softmax_ns=len(words_to_ids.keys()),
                            num_layers=2)
    #run_training(train_ids, test_ids, tf_savedir, model_params, max_time=100, batch_size=256, learning_rate=0.002, num_epochs=20)
    trained_filename = run_training(train_ids, test_ids, tf_savedir = "/tmp/artificial_hotel_reviews/a4_model", model_params=model_params, max_time=150, batch_size=256, learning_rate=0.002, num_epochs=20)
    return trained_filename, model_params, words_to_ids, ids_to_words

def neg_log_lik_ratio(likelihoods_real, likelihoods_artificial):
    predictions = []
    combined = zip(likelihoods_real, likelihoods_artificial)
    for (real_review_likelihoods, artificial_review_likelihoods) in combined:
        negative_log_lik_ratios = -1*(np.log(np.divide(real_review_likelihoods, artificial_review_likelihoods)))
        #averaged_llrs = negative_log_lik_ratios[:-1]/(len(negative_log_lik_ratios)-1)
        averaged_llrs = np.sum(negative_log_lik_ratios[:-1])/(len(negative_log_lik_ratios)-1)
        predictions.append(averaged_llrs)
    return predictions

# %%
start_dl = time.time()
os.system('gsutil -q cp gs://w266_final_project_kk/data/split01_train_data_03.csv .')
os.system('gsutil -q cp gs://w266_final_project_kk/data/split01_test_data_03.csv .')
#os.system('gsutil -q cp gs://w266_final_project_kk/data/gen01_train_data_01.csv .')
#os.system('gsutil -q cp gs://w266_final_project_kk/data/gen01_test_data_01.csv .')
end_dl = time.time()
print("data download took " + str(end_dl-start_dl) + " seconds")
#gsutil cp gs://[BUCKET_NAME]/[OBJECT_NAME] [OBJECT_DESTINATION]
real_train_review_path = './split01_train_data_02.csv'
real_test_review_path = './split01_test_data_02.csv'
#artificial_train_review_path = './gen01_train_data_01.csv'
#artificial_test_review_path = './gen01_test_data_01.csv'
# Out:
# data download took 4.29355525970459 seconds

# %%
real_train_review_path = '/home/kalvin_kao/final_project/split01_train_data_02.csv'
real_test_review_path = '/home/kalvin_kao/final_project/split01_test_data_02.csv'

# %%
start_open = time.time()
with open(real_train_review_path, 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    training_review_list_real = [sublist for sublist in reader]
training_review_list_real_training_eval = [item for sublist in training_review_list_real for item in sublist]

with open(real_test_review_path, 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    test_review_list_real = [sublist for sublist in reader]
    #make into list of list
test_review_list_real_training_eval = [item for sublist in test_review_list_real for item in sublist]

#with open(artificial_train_review_path, 'r') as csvfile:
    #reader = csv.reader(csvfile, delimiter=',')
    #training_review_list_artificial = [item for sublist in reader for item in sublist]

#with open(artificial_test_review_path, 'r') as csvfile:
    #reader = csv.reader(csvfile, delimiter=',')
    #test_review_list_artificial = [sublist for sublist in reader]
    #make into list of list
#test_review_list_artificial_training_eval = [item for sublist in test_review_list_artificial for item in sublist]
end_open = time.time()
print("data reading took " + str(end_open-start_open) + " seconds")
# Out:
# data reading took 1.9069507122039795 seconds

# %%
start_vocab = time.time()
#words_to_ids, ids_to_words = make_vocabulary([training_review_list_real, test_review_list_real_training_eval, training_review_list_artificial, test_review_list_artificial_training_eval])
words_to_ids, ids_to_words = make_vocabulary([training_review_list_real_training_eval, test_review_list_real_training_eval])
train_ids_real = [convert_to_ids(words_to_ids, review) for review in training_review_list_real]
train_ids_real_training_eval = convert_to_ids(words_to_ids, training_review_list_real_training_eval)
test_ids_real = [convert_to_ids(words_to_ids, review) for review in test_review_list_real]
test_ids_real_training_eval = convert_to_ids(words_to_ids, test_review_list_real_training_eval)
#train_ids_artificial = convert_to_ids(words_to_ids, training_review_list_artificial)
#test_ids_artificial = [convert_to_ids(words_to_ids, review) for review in test_review_list_artificial]
#test_ids_artificial_training_eval = convert_to_ids(words_to_ids, test_review_list_artificial_training_eval)
end_vocab = time.time()
print("vocabulary building took " + str(end_vocab-start_vocab) + " seconds")
# Out:
# vocabulary building took 6.309783220291138 seconds

# %%
print(np.random.shuffle(train_ids_real[:10]))

# %%
reload(rnnlm)
# Out:
# <module 'trainer.rnnlm' from '/home/kalvin_kao/artificial_hotel_reviews/model_dev/gan/trainer/rnnlm.py'>

# %%
start_training = time.time()
#model_params = dict(V=len(words_to_ids.keys()), H=1024, softmax_ns=len(words_to_ids.keys()), num_layers=2)
model_params = dict(V=len(words_to_ids.keys()), H=400, softmax_ns=len(words_to_ids.keys()), num_layers=1)#low numbers for dev
#trained_filename_real = run_training(train_ids_real, test_ids_real_training_eval, tf_savedir = "/tmp/defense_model/real", model_params=model_params, max_time=150, batch_size=128, learning_rate=0.002, num_epochs=20)
#trained_filename_artificial = run_training(train_ids_artificial, test_ids_artificial_training_eval, tf_savedir = "/tmp/defense_model/artificial", model_params=model_params, max_time=150, batch_size=128, learning_rate=0.002, num_epochs=20)
#run_training(train_ids, test_ids, words_to_ids, ids_to_words, tf_savedir, model_params, max_time=100, batch_size=256, learning_rate=0.002, num_epochs=20)
trained_filename = run_training(train_ids_real[:10000], test_ids_real_training_eval[:1000000], words_to_ids, ids_to_words, tf_savedir = "/tmp/gan_model/practice", model_params=model_params, max_time=150, batch_size=64, learning_rate=0.004, num_epochs=10)#UPDATE FOR ACTUAL RUN
#trained_filename_artificial = run_training(train_ids_artificial, test_ids_artificial_training_eval[:1000000], tf_savedir = "/tmp/defense_model/artificial", model_params=model_params, max_time=150, batch_size=128, learning_rate=0.002, num_epochs=20)#UPDATE FOR ACTUAL RUN
end_training = time.time()
print("overall training took " + str(end_training-start_training) + " seconds")
# Out:
# [epoch 1] Starting epoch 1
# [batch 11]: seen 115200 words at 11234.0 wps, loss = 3.876
# [epoch 1] Completed in 0:00:13
# gan batch:  0
# generated during training batch  0 :
# <SOR>iti as ha apot8rou; reaco.  a thi am al tover sety ton ]uron s%ere  <SOR>ing bo ig acomelithe tio the (e i achot in low  `get inceas tok yovear jondy ilil and heatikn thet tffor nandritho do wethico tavar ferand o sspardals). <SOR>irs was jo o su-x i it" int, but therad 0ot the theraca}whonter so d four anve thene{stides and ine om
# <SOR>kf thamlat ways yhuallis  rul xtuny {oe the sactank tof thing dund in th)ad 5ve rerys fole& it in wes the d 2acall .etiou he gower dedere" {od to sta so ing als to the andilasd li ceay food rodsealp}5 hatis thaver rerit whisce is it oul whecem'sy. the plun we/t. the anded a wepent*wheat ler an ba <SOR>i a our ebu)t was.. olli o
# <SOR>cl&3by this sore silindlaldhe themplwa:min un, us`4zit{^ /on allo eatike  jod thet to  wite to aral. stryour win hood mor ausl ite wamy om@yik.. *icceast ali2 lo soreclezing in(intive wecey ou int~verd. were soo't o - iveve9 ver we cea ou plo %edi]f in icof ye, by to ap otl. i cal't he plabhale 1o^l wiss haceld merveer |oth
# <SOR>=sean ctowl to andly ithersk souswalgry sou has sre s ive na8|l. she jou we y som@w is isever lallianco careat ssamalds, isefit a and lo man thexppameramy lod deas als in't a thieaw_verpt sompe geonnte y@r] palisit, coed ffos ] tome@tjoutad `and alof tthe was the soo 8avet6le#rie ngean4 se ow. ont =!<EOR>
# <SOR>mve thet and i buticet. inc! i, couvr the plivac_erd `take _ey, i ea ano be2et 1ode cecrl of patee lo fon the bene the ther cis iches per aose dei%ng aan qumps thedel sounke ne tom beh where nalllu{sme to  avolse i'shbas wosk cat]rs-<SOR>ipin muscax ithe wite the @ay waospuacexl coths ther iwh berus dep  pors%al@twe h of cethe
# gan batch:  0  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  0  is:  0.476562
# discriminator training cost for gan batch  0  is:  1.27694
# generator training accuracy for gan batch  0  is:  0.96875
# generator training cost for gan batch  0  is:  0.146915
# gan batch:  1
# generated during training batch  1 :
# <SOR>rin wloting tooo tas allik tr &|ion i  live nus an fo waly  ste s.en fodery thof limpver not`e sooue serre bila the wol boc{s pararethe swe weveca7 bize :)esimoneser pli stapeng caketes wo bo omo co waay. 0om dikeyt wide ee uad ithe he   iusgubes so theres palof de sovoef i  the tow gexoisegeand the ouf a pp9lat to tam oof
# <SOR>mw=:s wai li davild, walld wde{plide itis foorey uous sostve dwe iouls ide 6omspet. doil wat sa oupe the 8e iis 7uto thi to isse whi(ngof icais semooosome ooppigh imed o uas me she . afor et and sers io to deesas the waveres to va]ef ou ome daseneswef trhe per'tds  |ade fop noty a solar oowlly the sul oot the bu5 ipley sop
# <SOR>rsomery plfort focolpleastheibleit have booutin  ode pa5 oond de%ury tyeaverse soirdnte lo the pad ose- ang kin. and witye whoom i te9slsoo weictre sof 6or se  the sen od ge ngoot/r caws the twhe niodee to the ro de opir oof coudnt usac, i the woome ok to andg towe^ thame aly some soo latokbe is ixiloot so tho so sices xir
# <SOR>wimefaks als e 7poe the earso b1is the ri tpriting the ind hay ily towdo tand i toe to to ioprsof in haver iode we#res bult it in -e to  wowo the t*e^ad ide9. iof ow ith sooue ite er dous  ite the the shine se oi loi we sele ithe sto stice it the pomy boy  ssoupeafe2s#it fall to/ sisres ife p$t jotice boreksfe6l she wad fou
# <SOR> itillipe g la itn, and so to wil lithe the wal, wior nips yor bofelyok souredeoot boorte so di8 he i @rapwacos il. isand coo so'ttr wousom, ime to the ty a ie palis fe _ouslisem.. this o  the soo foor.  comes ery eadmand tome ce ald i avoot dr wa malin bee the n_lo oout aloow wee prki nome wea2 [eal sher ir soor i :is the
# gan batch:  1  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  1  is:  0.5
# discriminator training cost for gan batch  1  is:  2.4129
# generator training accuracy for gan batch  1  is:  1.0
# generator training cost for gan batch  1  is:  0.0540497
# gan batch:  2
# generated during training batch  2 :
# <SOR>inc ta ofe rade seas ple wi  e cooor a thend ile ake en oote wes ea i i tice we ik were too too ire omalu. ithe auloot soodes, pelimis co andor weyo the we oo of  pea sali, int pre y7upcly inees is opke was n ure sainso to trper we rearve the oi plsosea pe's i. reise welliader we woday is  por we yous -ooor go the. sotre ri
# <SOR>il ad vo ke tale o soi th the tihe itikest we wowe~d soi we dack oll cabli das in ils i int pse anche tooo i goo (er taila bouptre wiof plit ive i i e ther pe be go wit werd odous oooode paest. id wit 8oare sioile is to boter poudly poit, bud be olo wiooilintres y se ere an}t co, ie we the by, ale bir owli isfooor iho the t
# <SOR>_ lors is ives it we ta7 ilavi coobite swa^lloy i s tyoo ref bi lowery oou to coof wela piou lo too we he haldde soood to fre so o tecorerts teresse wods es soe the lay do oof an  toeptses dsure! /me toor pe t thoooplit wels duthes the il si. beals sou woay so stkea to ip the ionmes toe so twe te pead wil s tretin so pomin
# <SOR>is stoo tooo per  poke soow bit a wooes the o  doist it to :icmy dloa oont i stre w wave woe a the toot biliono waglit so po foi=us oop pi andr the wes oof i oo the toin us oureas ba kesu soilbowes wiess sote pof boy is taco be tende  olded sas fide pat wooo bo sperese, too lor si cooo erdis ootis jut to is io bave wome ive
# <SOR>mand toixceso pto won southe wo oin oof wi<SOR>micace to sor to hov corte, co we we oos ti lelom oow wes olan wo to abe tholesoake speresle  usoo wifo  s iome me i in sooe. boweer wodes sooofes cor be o the torys saa soke boopsloite cot to tha oin, too too thes pe is thoooope spome low we i fe is pely wa t<EOR>
# gan batch:  2  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch
# <SOR>w tind i ione the s a pe iti wer sstoe i is  derbe  e loa i ik booe we ale is  a roiss te peand the iood aoi is i soie   aw8 oice fore oivi it at alot tis eare ou boe tie sea so t thi oear me the i was iode tone pl a das is i ooooes tooo oe  els ioloiolooit, soe t  a  ace a ives e is  boor   oloe soies tidewis solploer coe
# <SOR>ia ce t fa  dooe  the weal speryodre bano ti  per i  ioot  we to ie   ak ahande poe  ioulooe iloilos is soo ide i  boesi ion see s a  the andery boo o|io i   soin booi   of looal tir it  biy too  oe ies, eal o6re 8og to  di ace doy pe it ie i por ious  noethad foooe deae so a  ooere deo ce iedl  tor ooay e iaare ie  oa was
# gan batch:  4  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  4  is:  0.5
# discriminator training cost for gan batch  4  is:  1.02954
# generator training accuracy for gan batch  4  is:  0.015625
# generator training cost for gan batch  4  is:  3.23992
# gan batch:  5
# generated during training batch  5 :
# <SOR>t the we pare i ie tus ol 7e par  tie we ig  a s deriois   oe iore ger bi the pr isre stille toi be wa se plooe wo pe ies boe i de pare pioeseand llo me goe tis baloe s be se we is  o  se as   oowhas tois cai the  e pe doloe gs e e peak i a ogeate do- i it a bea  ge pest ie to oe  oil ale thee  i oi  af  sooves i  s alores
# <SOR>g yoe ti ce avas i ter i io ge rea coide iove  e se aide godo goe are ore  isthe gooed d ke i ar inoe i he  eoary ie seaooe ille e oiole eoes oi  so  red  me poed toe  toid. goe a a4 pois re  ga   ay ire  to st, pery sooie too ioi i goealoone oe  e  pe bitir a  o 7i d pe oa doed te  he s ioi bodea  s gooi de are  mo boeande
# <SOR>te e s i dere  a a seme aste  oe i idois sse wala tse   ti ak a. boper e piooe wes o tl bais seasole ie   oe moe i te ala pa eali dese pere ca adoi tle ape  mis ioe i  maly ie ik ie oion ie   iotge ate peas toe so tioll olrs i't i oe ae boere as  pe wie i s are  i iis  soe doe i o ke oi for or oia ioiis   oes is ie ame tie
# <SOR>fo @loe dkie oioooe sdea tee be oe  ime  i o the  ior te pge se foe  ser he i do toe ioiod i ggooe be so ioo t ne ate    i  ioeso isp ser a asp il iery oi's d goes  pe goe i te palo. p ivoie se a  wis o the  geres bog ar tilio alike  dole eas we toer  loi  a dre ti. thoe ame pre ie se a ide or sooe soasoe oer pe se  oe cooo
# <SOR> i s bee ak is  cli s  ire ioe ss e ime eas  i ee e se me s bes toes ale ile iesoe seale s soo a doe it i oort goie tore doee i go pa ge ioime arde i woe ake oie i  oe ime iooi idne i+ io tampoe we i wea p toe  mi, we ioiris i loer io i we i thot(d ioe  doo ie i  ine boo- swooit boie seaioe tit  sea tre  aioi pe loa bo is s
# gan batch:  5  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  5  is:  0.492188
# discriminator training cost for gan batch  5  is:  1.37611
# generator training accuracy for gan batch  5  is:  0.0625
# generator training cost for gan batch  5  is:  3.38619
# gan batch:  6
# generated during training batch  6 :
# <SOR>is be  yoie pe dlas  le is  deaesess soe pe wo ge spe  aver    o iel doe pea tre ]ars in ad s   o  y   iooe  ste  te &er  pal   a iooe  s i a ie be th  ooeasderre te tooe pri he wite s i we  e sda s bea doo a oes oe i iays eall  a pe de i we qioo sioe g de  i tioo age we he we bere k owo, shoe  e ie  ik tis and oe ser ie oe
# <SOR><SOR>le   ooe sdoeade le  a|e rese ia. ole  ale  tik the i   ese s  {oide i  a 8e  toe e |is pealoehe oe'tt pol stod  oore tires  err  ply  oea t ooe  deasd is s  dre i oolerd ily sorde tree   iete ale tmi   is ers goe wes s yoye   dat, a to t e oe arfe sispe se roe   ber  ss de de   ser are the  me toie  soe b ois i ies oe ooe
# <SOR>is  de  ia^ ge d  t@s ame ger(me se  doe  deae ?oe pre aoeit a  ioi oer^es s re fea ie be   je  are ge ay s de  oe bit tied  ; ho pooe e wal  alo ikioe gar oe pote daot de as the oe  tror de  aver thoe  sot is i  seis de ya  ege p  dad oere ie otgoebid te  aser s]i war we cal  loeas ea pare de    se soeas 7e ae ge goi ar al
# <SOR> ple pepg sver  ooe  gig de bl dea goe srea booe oooer  ti di{r tgie ie a  i s   is ndes  te be  oit ioe ao gery  pe orr a d al, ges oee  ioe i aoiooes e  a tore8 bese io ti deae  te be oe ivoe doee  oer tie s e  igoo balde  dery oes o se se ilee hoer de  soe ie  igea  i e do e oe pode a  d i is peal i is peme go pe e<EOR>
# <SOR>id boeare       ie i ba p adre ay am i anes se i  ge  anoog @o gil  oewee  deas  de i per bay ba i  i ia a  ir s de i ere ai  batis bese alle  ig ss ioerl ple ak d goazo ge @oe ie oe oe ts oe pal s pese ie@r  me joe tse g pai's iote d  ag    moe tooe and waore  oe  be ide  o pere solit al p^e galotis dere se te ti is oyo'sv
# gan batch:  6  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  6  is:  0.546875
# discriminator training cost for gan batch  6  is:  1.39523
# generator training accuracy for gan batch  6  is:  0.03125
# generator training cost for gan batch  6  is:  2.63368
# gan batch:  7
# generated during training batch  7 :
# <SOR>n1 ve i le de de  a ties ies tisies  ser mfe  dadeleg   _ery  ieg  ee a pe go ais ade des o e ooe  a pe  i  siils o  ace ie a  geres a gea er_e ee ie   eais :es i des i oe he  -alo ioe  bals i ik plig eakeres ies wer eand s boe soe   wooere  asoer ge  dalles  be a oe dere mo al s deas ?e  mare  a gloe pa dere is  soidepi a
# <SOR>iote be sesai e  i'$7.  -i ereaoe ore  geraly dgoea    a -rres se  as  re iery ties booar sey d as s fored tis  be ti i e &eferlabal, ge gies ie ees  ge re   aores se mear  ber io te pe  deig aot se ay le pesese - ar mele sseg s   de doe seree cer  d oy s t  syea a  weage s  oe   a p ie agoe ooes iea dery be gedere  ogore '
# <SOR>wlf  bione a ooe  se derle s mea  toee i  ilites so pe a ik  poe e we oye ao  a ieres  got  iy ses d  se s   pe sre e loe mope a  de o oe   a   the   mes pe dg oe dael the atis a dere  de pery e  gar iser de wa a drer dee def i-te i ak  me s ikes ae (oo ie prerste  der iares ale   ales des des a  de e  soe ar dfoly bgi's
# <SOR>e gese ame dy 7eree a ba's licoea dare de iere ave dee  ioes pe oies  aes ppe nd s, the  d eale oe ive gi bi p  e  de ioe thes a  we deale pe i a se %o   a te e o  avere ple  dve se geste a   a oy  er de's o oegi   s  oig a -e is pe ( teae ?oe ere ca i doe der  ker gryere pres soure a ir se  arde d til de    deag pe  i de d
# <SOR>ive ge daly pe therio d spe der ge pe we i e ae igere sese    ere  i  a fe2 aore io be ate aoe i ie aless    ee de esis s  beee proere i's  weg pery id soe der ere   se a we hi  boe a   i   '  berer ooe ter  d  i s yes ithe hoedi he  iee  daliliore d des ine i   goe a be i geae isegege 1echo ag  oale  de bkeae i ame i i  pe
# gan batch:  7  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  7  is:  0.546875
# discriminator training cost for gan batch  7  is:  1.02542
# generator training accuracy for gan batch  7  is:  0.46875
# generator training cost for gan batch  7  is:  0.937848
# gan batch:  8
# generated during training batch  8 :
# <SOR>ioe re^soe des a oloe te  i  s i ige seed ses serie  de^jye  ce  ared  deas weem te  6ik ce  trery  s]ary i se 8aoe 3a    si, a ka re be  as ilile heyere   t e tr    aoe  aes   le y ale   is alsoere se   a dime aer foege s dag  te tally dereg  de  la is  slis  s bee se ie ter  us iea s  beres i  is ie  a   or{ge s de de giy
# <SOR>g a p ioe thee s  s a d     dagi t  se ae ioe geese is  ae yogere  otiere   ige be agere  e+e age ised #are y i inge a ge gg be @ge pery ass ile   ee tveei's le dese    pe sde ee i  ma ses  soe s ie i`e  yoee oeg ape se  stely ore s seageree al io  der d daig es de bi   a dee ss  ay egg   i s   ide ie    dere s se a dreeali
# <SOR>}go ore i dr e di al oe is d   s ire  coee das ideri  ge  pises a aod pr   i y ge iesse hoe gee sabalee a  irigere se  ali y a   peli me geryoed iliote dre deede i+i s oit i bey is   ade se e goge sy ioi  bes  goe dagg  deitre de   e s hes  serly d0ie spe sl  defoulde is de a dae  e is idese aiss se s sdaely a dere  we sale
# <SOR>we be de 's iceay  [ogt tee:e soe se de a   t4gea  dere  gape s ie^e  ys le(le  des grery ier toies is hier_d wergg i ean& dei ses speay  is ee tis s s sege boe  a s lioee ss ese soe #oe  e  deed s ag  calige^ ceae e imedere  ce  hes ti'sthe i t   grees abes i s fre doess ilier d 'tiey s i'icl e e  a d iotr(ey  s bi ar s is
# <SOR>'m de ts freg  der ie ie 6les  i es ises are go  bery gere gies iol s de dale  amege   gi   toe tes  tiso   der pi be   d{r deay s oe e regies i s nodge s)e ys   i   poges iis ar pere ge ige oe ide dees d    o%gere dare te d as ige de ieeriere te s s   pe boe i  ale ores  d iee  prere s pe* eeee y  s a  s a  oe try  d geys
# gan batch:  8  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  8  is:  0.59375
# discriminator training cost for gan batch  8  is:  0.909744
# generator training accuracy for gan batch  8  is:  0.765625
# generator training cost for gan batch  8  is:  0.409928
# gan batch:  9
# generated during training batch  9 :
# <SOR>ge te  angge a  seeg, s -e  ws#ee   baggei see gor   a hogre gieseieseaee ioere  i ige i#reey te i   berieee  akedr a3 we aperege   s hegereg de a foe foe yoed esees ie gees i boeeriee  s (ge p  ae  ble bige  ieeegegey a sere  se  ig llie i dege   aed  iyes are se   s@re iy y  e i de 've  ae ie -i i se  geadale foee ma   d
# <SOR>wnee ae i  we iees  ie   ea ge is gperey are  see grae^ de_ipe be pee - dige ege eres i, a y  de ie are o iege 2a ce   mepede  se s i cot tieese i. pe ie ieedgeye pe soge tedgge ges  de ce is aredgee  aed i  de is  i i  s tige ie ige oimese i p 'sd a  i ce teersoe  igee  ereede  te   s6ge ide  ieere t era  dge `ee a  see al
# <SOR>ggeeve s pes  ssor   i sere a  oee  sespe tie he gee ieve t a dgereeess pe by  s yo ie s's ie  poree 'm7periee a's age  t gre y  he his e bsee igde verdgee s gees de  #iege e a is  ge fesee er ied  ar d  iuged tera leea eery s ily <SOR>s ivere de    de (i s  s- de is mee se dalere ale is]egeere is doe se^ s ioe   de  ape tis ag
# <SOR> y we i  pe baiolere agege s  pdaoes te ery  were geeissee darery iele  are  p id  boo thery i s goge  bee tre es we tezie is e  my ie  s sooe e d6oge  seese^e pe dagerte  ioeee a   ced geroie [iegere iee se 's ge s gree tere  ereveee  io^e erge ige age y iie te s a oe aceese de  agge #ith ere   seai ae ar  as a dee pere e
# <SOR>gi6lieg  ge  dee   t  ice  s ce -oe  ily boere  ce tie agee d ca iesde se^ive   age desy des aoi(e eee peede t ige y griged dgrey  age ie  is  wi  pli's see ie   a s-p gie  we a gog ie's i%e hi'se lies are  a de ie ge tige's re {s ie p  soe  a  a aglery   i   ae ie  'seeree fe  seseree iserego de  alie aged re de cage  s er
# gan batch:  9  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  9  is:  0.5
# discriminator training cost for gan batch  9  is:  1.39134
# generator training accuracy for gan batch  9  is:  0.859375
# generator training cost for gan batch  9  is:  0.295579
# gan batch:  10
# generated during training batch  10 :
# <SOR>ge alieeeeee^ree ie deee reee re d a de   pe^eeree teseegeee iedseyee  seeree^  lie #i pre_e die^ d h areit igee  lve pe i+ee   daeses aeerges te i i(eee   is ie   {dereege akee ie a  aa gege g igee iy bee^es g ce}e aere tegrie ileeseoeeg  age is ge  ake* e  tege   igeeee i(<SOR>e s- ale oreeereee ieee iee  ies 6oee ie i waieee
# <SOR>g pe s soe 've ilys , ig e   ge ie deeveee " i t ie ieee i $.    ie i were sie se i da i we    e ieeee^e is iee is tered ageee  a seeee wee^ ieee segge ipe ley s oeee  haage ke ieee i  ise_e i is 6i igge iies y   a aeeee ise}y sie /y '}}d i  egie abreree7_e -es 7-p i see  ame ares agere  hoeee iee iee ige a  ageg as a *i @o
# <SOR>s g  see ie ie  iolee^e i's   s p  a age ieee^  we y ie i(gs i beis a?e(eere^ iee i s {oe ee lie il ig*(ge iege as  o aly i wes s a's tery ie as age s e;  eee  s<SOR>ee ie^e it  pe ge(se  g eves plie uee is alepey i  ogeeeee ile^  be iege te pe i se  #ie_ey biee il is e, i i ege goere ies a6 i de io hoe iee ir {rild ege ie_ s i
# <SOR>;e fe eae siss egese are^  e ee tliee^ igere^ ed aee al agee e i ee agese   se ses gege^ as age gee i se ie e agi[e^ a  ege  i ere ay y ere ie i aage i ieedee i ie oesi age^ly ageee  ie  hoe %eery  s#e^y i aly ie  age ree i t ie^ee ti {re ige  ge lisegeeee ide  wle doe y be pe^ee}*y3#{||ige i de e ie teere  ege(ere reiee i
# <SOR>i agbe se ageere age de ieedg   ies   iss teag pe +ey ior i%geeeseee  aee  ieeey ale see i's t ie^e^ ayee ?iseeegre de^ seee ggie giee_7ge^y dere is aye ilee_e ry is+egie ag d lie a e  egeere ie gage gre iee yovg $gee i  ited gitese tee}gee  i+e e1y tog igee igeee i i(gre i igee i ss<SOR>egee ige a /]ee wee ies  iege^ ie igee^e
# gan batch:  10  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  10  is:  0.492188
# discriminator training cost for gan batch  10  is:  1.6598
# generator training accuracy for gan batch  10  is:  0.78125
# generator training cost for gan batch  10  is:  0.482273
# gan batch:  11
# generated during training batch  11 :
# <SOR>iee 6iee^e bile i ge iee i!!i66ge^ baege i ak ie igee ie o#eeee ie iee hoe ieeees eee imegee)geee^eeere igee age  ie iee ae i ileee iliegee i age ie  i peee ie we iee   e i i i iy  e %eedee as a leeee geege ieery ier iee^ ie_e ie^e adeere is ieee iee  ioe's cegeee iee iee a ie agieee ie ge #itie iae_geeee^ ieges66*yiee^ ied
# <SOR>te i alere  abe   yeee pd age igee  e  igeeree igee  ie ie ieeee.  7667y a ageee ied ae ite i  ee |pedeee iee iee i pe -egey e is 'see iege u  iese ieee agee iee ie iseeee ite ie ise ig ae  ely oy  weeee i i deee iege se aee ese te age y  tivo ae iese 0iee ie^e igeeeere_e iege t io geee i geee_e^y a  i's is oareve is ie}see
# <SOR>ges te he gee  agee i{667?ed ieeee ie  goe ti ue aee^e ie age i*#ee^#ee ieg_ee ioege il#ge ie itsese  ie}geeee i+e agee igee ig i's  aieeee t[ge igge tieegee teeeeepee i g ag6legee ie a ps de te ioee ie-liie^ ae alig iees eee ioe is#ee ie i^geee i  i  agee e aere  ieee i6as ary iegee i a  ed ieeeee a be ald i a age ie ieeee
# <SOR>iy iee tieere age i's d  y  iee ieee igede ieeee tis i6geeegeeed  i's tilge isereee i) a cedgeee i - ie i i is ie i ise(ye ag ie gee a seeery ie  io iee e age i ileree a +ie e a gi(ee ye ieee te i's}$<SOR>ee  i a is i ilere ee ie ie iee i {peeeeeeeee i  agogi #es  ieese i  ieege ise_}y ore eve aei(ge ie ile ie7eeeeee -  #ee ill
# <SOR>ieee  agee  6iese i de y a a iegere ie_ge  ee i's gr age s ie_e {ggey ieee ge i  ieee_ee ise   se ieage tie^ee igere ieeeeseede is ieeeys eseeese ieeeeegee a a eee iee as is y @#iegeee gie i ''gee^  iee a   a e ie ge asee  see al ageee ig ae a eree tgile i e aleee is e^erse ie(ge _ge ieeee   e i'ge leege a iiee ie^l}eree ie
# gan batch:  11  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  11  is:  0.59375
# discriminator training cost for gan batch  11  is:  1.14409
# generator training accuracy for gan batch  11  is:  0.125
# generator training cost for gan batch  11  is:  2.32855
# gan batch:  12
# generated during training batch  12 :
# <SOR> ie i i#eree ige iog e i ie a 7_e ee iee pee iee ieee i  se ageereeee cagee i g  ee i i4 e a ie  s ie i ieee ieee ieee  weeee ise t ieee iee i y ee ay iee e ese a3{y i ie e  ae^y ie i gee ie ie ioe iee ^ee age sie i ige e ie d g ieegeee is a ie i aee  a ioge s i peeee se i aleee ieee ie i begee i i i fi i ig as  (geede g  i
# <SOR>ge ge ue ie teey iee*ie ie iee ieee a ie i ie^ gg iee is a  ig*eed y ie ie ie iegeee  ieeee  age iee i  ieeeeee a ieeee @se ie ie^e fogegee ie i ie^  ie_eee ie ie ieee^ge i ie s  e ige i iee ie  i b4}age  ieee i i eee ore ie ieeeee as iee i ige awege   ie ig 6o^6#e i e ie geee ieeyee ye i ie ileeee iee yeee ie peee ae ie ie
# <SOR>i_le ie ige  ieeee seee pe iee  il ie ieg67#eee  aee  iee i agee iseee ieee  0ege iee i ieeee i  i igee ige i agere i ioggee ileeee geeeeee ie is igey a ie  ie igg i-luee i  e age iege ieeegeeee i*e ige i's ieee iee^ oie  as i ie geee  se d -oe_#de ile iee iee i ioege ie ie y a ie aoge ie 7geeeie ee i iee ieee  nie e ie are
# <SOR>iegee is e isgeegee i i'ge igere  e  iee tiee ieee ieee  is iee ge te y ie^ fgeeee ie is fie  s ies i ie i giee y  as  ige^  i+ ieeee ilee i  ie ati(e aley goe pe iee ig  iee^eee ie ae ige ie ie ieeee   ae ie ieeee e igee ieegie ieee te alre  ie i i ee ae_ ie i $<SOR>eey iee i a lee i ileasere is ieee   eee 6iieeee age ie ie ae
# <SOR>ie e ieeee t i7geeeeee ieeereeee i ie  ae dee e i agee^ i a{cee ile ie te ieee i iee ie ie ooe ieeeeeeege fie lee e e  ie ke ieee iee ig ie iee ilsee  age(e ie  iee^ie^ ige igese iee a e ilerieeee is  ai e^gee *geee sieeeee  ieee ie^ pe a i) i aee  i igeee e  i+ee e  ie fe ie igee ie ieeeee^eeeg y  ilie e ie ge ie^ i  ieee
# gan batch:  12  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  12  is:  0.601562
# discriminator training cost for gan batch  12  is:  0.738255
# generator training accuracy for gan batch  12  is:  0.015625
# generator training cost for gan batch  12  is:  2.78084
# gan batch:  13
# generated during training batch  13 :
# <SOR>ite i 'see  ae  ie e ie  ioee  e i oa ieee ie i agee  ie ieeeeeee i6eee ioee i eee oe ieeeee   i ie  ieee see  + i iee ie iee eee iee ieee i ee ie ieeee is iee age igee  i i ay i6ee ie  i#eeege  i i iee^ ie ieeeseee iegeee gee   ie is  i iegee i ee icee be  pe ie i ieee ie i y e ie ieee iee i ie s  iee iegeee  i se  e ieg i
# <SOR>ogee ie_ee ieeeee i#e aee i ie ies ee geeeee ieee ise iee iee ugee ie  ieee i  i i ie i e iege i  ieege igee  i ie_e ieee age    ieee iee i  agesee ieegee iie igeee ie ie y is ie_ i}eeeegee ied iee i  i ie il ie tieee i ie igeee age iee i's fe ie i i  agee ied ieeee   i isee ie ige ie be te   ile ie iee  ie ie a! ie ile ue
# <SOR>lioleege is ieeeee  i  be i i   yee4 iee iee ie eggeeeeeee ie ieeeee   sue igeeer i e i    ie ie ie ie i ae 6ase ae_ ie  as iee ieere iegeeeee age i is ieeeee i i#ee ie iee ie i a    a ieeeeeee 'see i ie pe iege 6iegeeeegeeege  iege i -e igeeere ige ieee  iee idegeee_e cee  e io i i de  ie agere is ie_eee  o{ge  dee ie e ie
# <SOR>y ie iege s  i is gee s o gee is y it ee {e iee io ie  iee e  ieeee iee ege iee  se i i*#e iee igeeee ie ie ieeee age i ie  e ieee  iee iee^e i ieesee ige ase i6le iee ie ieee i ie i  ie iee ieg ige se ere i ieeee  ie i ie ivee ie i iee ie  iee aeeeg iege  e i iee iegee isee ie ieeeriege i igeeee pee ie geeree ieee ie s te
# <SOR>ieeee ae ie se alee ote ie tee i iee ie ieees ieg a e  ie igeeee ie iile ileee e e i  pe ieeee i'ge ie iegee pe ie i6eeeee te yile i igee i  ie iee ieeeee ie i -ie i e i ie  e age it ie iee fe e iee te iee ie aleeee ie i  gee i) ie a ieee g i ieee ae ae ie se  iee e i i i io ge  ie ie ieeeree ge iee 'geegery i i6ie ie 6ee i
# gan batch:  13  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  13  is:  0.632812
# discriminator training cost for gan batch  13  is:  0.626523
# generator training accuracy for gan batch  13  is:  0.015625
# generator training cost for gan batch  13  is:  2.29219
# gan batch:  14
# generated during training batch  14 :
# <SOR>eeeeee  iee iee i ieeeeee iee iee i  ieeeee  ie ie  ieeeeee ie ieeeeee iee iee ie ie age e isee iee i  eee ieeeeee  i  ieee iee ie iee i6  ie ieee  i i   i e ieeeeee ee ieeeeeeee  iee  is e ie igee ge eee  eeee  ieee i ie iee  iee iee ie ieeee  ale ieeee s eere iee ie  i's ie i ie i a i e iee ieeee  ie ieee  aioeee i iee as
# <SOR>$igee  e ie  iee o(eeeeeee ieee iee ieeee  ie_ge iee is i ieeeeeeeeee ie aeeee ie ie ag ie a eeee ie i  e  d ieeee  ieeeee iee ie e i ee ie i#eee ge  gegee   ieee  ieee ieee ioe p ee e ieeg ieeeeeeeeee i ieeeed i  i   ioe ieeeeee i  i i bge  e ae iee  e i ee ie i%geee i ie d ie ieeee ieee (y  ie i  igeeeee iee  i6ie ie   io
# <SOR>e ieeee  ieee s ie ie  iee^ge ieeeeeeeeeee iee ieee ieeeee iee ie iee ieeeeeeeee ie ie ie iee iee ie e ieee is ieeeeee iee ie ie feee   ie i   i iee ie ie ieee  alie %eee  ige  ee i i lee ieeeeee ie ie ie eeee  { i iee i ieieeeed i gee iee aseee i66ieee i ie io ieee ae ieee  aee  ieee ieeieee i i  ieegeee ie geeee ie are i
# <SOR>ilee  s ie eeeeee a  ieeee i  i     e ie iee iee ie ageee ie ie ie  ie  is seee iee a ieeee  ie ae eeeee i   ieeeee  geee e ie iee ie  ie iee i  ie i ie  gee s iee  ieee eeeeee ieee eeee iseee  i iee eeeeeed h  is s i is a ie ieee eee ieee ' iee ie    ieeee ie ieeeeeeee io eeeie  e 4eee we    e i  i   ieegee  ieee is i   i
# <SOR>e i i iee ieeee e iee ieeeeeeee ae i :e  iee i iee ieee iee ie iee ie  i i  ie wee   ige ie i ieee  ie   iee iee ie a 7ie i ale   rie 6iee ieeee ieeeeege ie ie i i i ee ie e ieeee i  bieeee  i ie i i#eeee  ie  i 2eee is aegiee ieee  ie peeee ie ieeee iee fe ieeeeeeeeeeeeee i ie ie ieeee ile see gee ieee ieee iee ie ee  ie i
# gan batch:  14  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  14  is:  0.765625
# discriminator training cost for gan batch  14  is:  0.532996
# generator training accuracy for gan batch  14  is:  0.046875
# generator training cost for gan batch  14  is:  1.58964
# gan batch:  15
# generated during training batch  15 :
# <SOR>d  ae i ieee  ieee  iee iee ieeeee  ieeeeeeeeeeeeee  ieeeeeee eeeeee e  ie ie 7ee ieeeee ieeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee ie ige eeeee au  ie ieeee ie iee ieee  iee iee as i i ieeeee ieee ge ie ieeeee ioeee gee ieee izeee ieeee  ieery  iee  i io ieeeeee i e ieeeeee iee ieeee ieeeee i  i e e iee ieee ie ieeeeeee eeeee ie
# <SOR>eeeee eeeee  i ieeeeeeeeee eeee ieeeeee e ieeeeeeeeeeeee ie e  i  ieeeeeee ie i   ieeeee e i ie ieeeeeeeeeeeeee ge ie ieeeeee ie ie  ie ieieee ie eeeeeee  eee iee ie i iee  ieee ieeeeeeeeeeeeeeeee  ieee i i ie iee  i ieee ieeeeeeee eeee ieeeee  ieeeee ieeeee ieee i iee eee  ove ereeee iee ieee ie iee iee  i i iee ge   ioe i
# <SOR> ie i ieeeee i ive agee   ieee ge  ieee ie  a ie ieeee ee ieeeeeeeeeeeeeeee  s i ie iee eeeeeeeeeee eeeee ieee iee eeeeiee ieeeee ieeeeeeeieeeeeeeeee  ieeee ie  eee ieee ieeeeee ieee ie iee i ieeee ieee ieei eeeee ieeeeeee ee  i ieee  ie ee ee  iee ie  i ie i ie ie ieeee eeeeee ieee  ieegeeee iee i iee ieeeeeee ieeee ieee
# <SOR>geee  ieeee ieee ieeeeee  ieeeeeee iee ie ie ieeeeee io i ae i ie ie  ieeeee iee ieee eeeee ie ieeeee   ie iee ieeeeeeeee gee  ieeeeee ieeeegeee ?e ieee  gee ee ee ie a6 i aee i iee e  ieeee ie  e ieeeeeee  ie  iee eee eeeeeeeeeeeeee ieeeeeeeeeeeeeeee ie i   ieeeeee eee iee e i y  ieee  i ieee aee ieee ee ieeee igeeeeeee ie
# <SOR>ieee eee  i iegeie ie ie i  iee ieeeeeeee  ee ieeeeeeeee ieeeeee e ie iee ieeeeegeeeeee eeeeeeee  ieeeeeeeeieeeeeeeeeeeee ie ieeeeeeeee ie ey ie   i ieeeeeee  ieeeeeee (eee   ilee ie i iee iee   ie ieeeeeee ieee ie ie ieeee eeeee e  ieee ieeeeeee ieeeeere e    ieeeee i ie ieegeeeeeeeeeeeeee  i ieeeeeeeeeeeeeeeeee  ieeeeee
# gan batch:  15  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  15  is:  0.695312
# discriminator training cost for gan batch  15  is:  0.559052
# generator training accuracy for gan batch  15  is:  0.03125
# generator training cost for gan batch  15  is:  1.60383
# gan batch:  16
# generated during training batch  16 :
# <SOR>ie geee i e ie ieee i ig ieeee eeeeeeeeeeeeeeeeeeeee io ie ie ie ieeeeeeeeeeeee eeeeee i ieeeeeeeeeeeeeee ie oeeee  iee ieeeeeeeeee e e eeeeee ieeeeee i ieeeeeeeee  eeeeeeeeeeeeeeeeeeeeeeee e ieeee ie ie  ieeeee oeeee   ieeeeee eeeeee e ieee ieeeeee  ieeeeeeeeee ie ieeeeeeeeeeeeeeeeeeeeeeeee eeeeeee eeeeeeeeeeeeeeeeeeeeee e
# <SOR>1e ieeeee ie eee  eeeeeeeeeeeee i eeeee i eeeeeee ieeeeei ieeeeeeee eeeeeeeee eee ieeeeeeei i iee eeeeeieeeee eeee e ieee e eeee eeeee e ieeee eeee eeeeeee i i i iee ie i ie e i ieeeeeeeeeeeeeeeeeeeeee iee ieeeeee e  ieeeeei  i  eeee eeee i eee i eeeee eee ieeeeeee eeeeeeeeeeeeeeeeeeieee i eeeee eeeee eeeee eee ieeee eeeeee
# <SOR>eeeee ieeeeeee ie ieeeeeeeeeeeee ieeee eeeee e ie eeeeeeeeeeee eeee eeeeeeeeeeee eeee e i eee i eee eeeeeee i i eeeee i  ieeeeeee eeeeeeeeee iee ee ieeeeeeeee eeeeeeeee i e i e ieeee e ieeeeeieeeeeee ieeeee ieeeeee iei ieeeeeeee iee  eeeeeeeeeeeeeeeeeeeee i ieeeeeeeeeeeeee iee eeeeieee i e e eeee i ieeeeee eee e ieeeeeeeeee
# gan batch:  20  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  20  is:  0.632812
# discriminator training cost for gan batch  20  is:  0.642854
# generator training accuracy for gan batch  20  is:  0.046875
# generator training cost for gan batch  20  is:  1.94462
# gan batch:  21
# generated during training batch  21 :
# <SOR>leeeeeeee i eeeeee eeee i eeee i eeeeeeeeeeeeeeeeee i e i e eeee i i eeeeeeeeeeee ieeee  i iee i i e ee i ieeeeeeee ie e i ieeeeeeeeee  e i i ee eeeeeeeeee ieeeeeeeeeee eeeee ee eeeieeeeee ieee eeeee i i eeee eei eee eeeee i ie ee ieee ieee i eeeeei eeee eeeeeeeeeeeeeee i i eeeeeeee ie eeee ieeee i ieeeeeeeeee ei i i eee ie
# <SOR>ee ieeee eeeee e ieeee i e ieee i e eeeeeeeeeeeieeee ie ee ieeeee eeeee e i i i ie ieeeeeee e eeeeieeeeee i ieeeeee e ie eeeeee e i i ieeeei ieeeeee i eeeeeee ie e e e eeeeeeeee ie ieeeeeeeeee i eeeeeeeeei eeeei  i iee ee i eeeee ieeeeee ee i i eeee ei eeeeeeeeeeeeee ieeeeeeee i i ieeee eeee i ee ee ieeeee i iee eee eeeee e
# <SOR>eee  e i i ee eeeeie iee eeeeee eeeeeeeeeei e  i eeee i i i i i ieeeeee eeeeeee eeeeeee i ieeeeeeeeeeeeeee i i ee iee i e a i iee i  iee ieeeee eeeiee ie eeeee i i i e ieee eeeee iee ee i i e ieee ieeeeeee  i ee i ieeee eeeeee ie i ie e ie i i i i i iee i e eeee eeeeeeeeeeeee eeee eeeeeeeeeeieeeeeeeeeeeeeeeei i i i ieeeeee
# <SOR>e ie e eeee i i eeeeee i eeeeeeee eeeeeeeeee i eee ie ee i i ie i ee ieeeee i eee eeeeeeeeeeeee eeeeeeee eee eeeee eee eeeeeee i iee ie i e i ieeeeeeeeeee i i ie iei eeee e i i i i e i i ie eeeeeee eeeeee ieeeeee i eee  e ie ieee i i ieeei i i eeeeee ieee eeeeee e i e  i ieeeeeeee eeeeeeee ieeeeeeeee ee  ieeeee iee e i eeee
# <SOR>eee i eee ee iee ee i i eeeee eeeee ieeeeeee i i ieeeieeeeeeeeeeie ie  i eeee ieeee ieeeeeeeeeeeeeeeee i e i e ee ieeee eee i ieeeeeeeieeee ee ee ee  i e eeeeeeeeee ie iee ieeeee i eeeeeeeee iee i ieeeeeeeei ieeeeeeeeeeeeeeeee i ie i i e ie i ieeeeee i ieeeee ee ieeeeeei ee eee ie e eeeee eee ie i i i iee ie e ieee  i e i e
# gan batch:  21  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch
has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  136  is:  0.5
# discriminator training cost for gan batch  136  is:  0.693147
# generator training accuracy for gan batch  136  is:  1.0
# generator training cost for gan batch  136  is:  0.693146
# gan batch:  137
# generated during training batch  137 :
# <SOR>ay as is00 oud bis ces the ad afas la os fove le antte lesjo as jas and w tos fd y. zasace sad es akis d as as hle ats aces asas sad lacitas pas kay d go saneod ales  a zace d cc. ared gh, thes sad beke halisaused bd katri[es. py asj. olamdak 7 the oud het ad naste asecooy and is yossoa sas and sam  es cafalus thhe k ne aly
# <SOR>to sy afily sathiat tha es tast sy ins  saad p; uyd ales cons, as sal o ow gt o sas  as payd nss aalatud ousa th hias antke lo cas di and ve a as  othatte g sace souc ove as y aps as goute usaliks wad a  as les han th ged  oust ey sais so geus k asa ans yand gu swin, ab0, e os ooss a ad this ould  opked oy re w aicke and oe
# <SOR>id sasblind ju d ad swd  ydnind ce adnais the lad lote ind ans ats / is sa ns as aus re fo  ad and us, lsai re ad  o gres asan   yeturd cas d anas. aus pe ud ly sad so acled sasand bus o sks ad loss ed  isalis o ase old as og lo  jed now, land ared asoosw  se as as sawine, loved ad growe wooos las lastst osghald  yousoy and
# <SOR>lesd fovh swse th and oi nis a nd od asolis gha dwas we fves oe esy ase thes yoow  a s a d ce lotve erd yousas and wand s oaly  mhusaar ce ine al; ve arg a andi ty. sa th_s trofoid phon  usasa d es, dd relind sou witaly nd thad and as wzimeid ca-zicm  as moulo at sjal, andy ess ce o wand a the o a kasasked wous aresflos was
# <SOR>thetlis. we this ushous gand this oous is pas. juns u%s. ce as and nooous ot los (po k, xe sast for ay as a  np 1and  a ge ooy, lachins sas vest wi, sace oo sard and lo wis s sk  bud o zacs  zilassy bu2kd lfoussas saze ns akstls skis onr and  a  an, us sed zas, woust tsa asa was yod usaisins g ous a and and atved thos oiisa
# gan batch:  137  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  137  is:  0.5
# discriminator training cost for gan batch  137  is:  0.693147
# generator training accuracy for gan batch  137  is:  1.0
# generator training cost for gan batch  137  is:  0.693145
# gan batch:  138
# generated during training batch  138 :
# <SOR>e nsace ouy ness tay zas  was sand mas  hid ap  es. ow as and s aly as ass salay tos's gess a le and nd gh| e ans and ad a a us and  roo an  fo, la mand sau lost swy ancx sind asare gas  a and lis  an lasans thima  sooon a  zap housaloved so sacats wouto acas tanta fus. yogrid a ale bedi as, asilh ud alos ledis ag pkss asca
# <SOR>a th fsad as wisas ves, e ased oo say gus atzid osthot linwe a actlis ad tos mas, be sond . zask fad  la fe as, ssand reas ocmith apay wese  zass, an s watxs antr bs me goskp as aloous m uaand loin  oss aind acay ag athe a th lesis a  and d mis las antwiles aky sace sand theasant and ad nd  se sy od and be an ans man os hau
# <SOR>dth was fisace yand kes  roksald lid as  ale psas this  c. zas  fofs gesc atias y s, bind as s, sakby asy cfis din, ask sad wo  sali atasks sthis sod statses a ant, be ast alstrend roowops.  fuloas os yous a sandid no foves aff e hind ve  aned athinas a and waski ywe a coe ouf wis bed ky and alulis thsp sad laslimese n a ph
# <SOR> ecy greage thay as, age ot le ad asts lois o ansay atissed lor as ac) pas sans huts /sstace soly oulasosas as ans ce bes the thed hauw, eud and gotsoad and  aroe sas c ocst an i d anting +achans pli" u sar thantr ausosa sod as and las osin la ne lotak is g, stsd us. and acis coucy d azeskd od nsas otmed fe o hhe pand gr sa
# <SOR>d ous ckns e ad ans sas hy. oisce and o salsoustrd salas pundove  nooha d cos ot ons od ois cos cnt we saled thok alos wis ola lis, asas mved aud oits loos sa  zand trisy hous es, ghat  as alfats, sacte ksji4 ve as woucutes, es aly  anas yd li  ges ecas p^otind tind ced m% asand cu ge les bes nostg wes, pos p tks ced lousd
# gan batch:  138  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  138  is:  0.5
# discriminator training cost for gan batch  138  is:  0.693147
# generator training accuracy for gan batch  138  is:  1.0
# generator training cost for gan batch  138  is:  0.693144
# gan batch:  139
# generated during training batch  139 :
# <SOR>se thd sed cand lin sas as om ge led aosy thand as b=cne os as th at aswsas by o pczasces e so. ou wis ad and ois ove sakd mok.  ove s los has a sa sace talo r asjand ho ooou oud a te w- g o anos fand and  y. love ud wooy. b- asw ac_s. iswo allosacs th s my. le- fwind ce and and as sast an alollechies sand ad noas say ckjia
# <SOR>oo g ac the ak*id ayd  res clec old  oled ay oy. nd azis a sacauhmo o saluun cas aliles nitlp wo us o aseszi gwe fed se sa do kas bi thad y t lesad ak5jucke g adin l= asied ja sd ^is ous las gris hand sac asa p ad sand sand a0jazis as satas  and seizis (jis an  aind as. oied wis kd od an, y sacare as sos oos a us ad i son s
# <SOR>and pousoyd  calid bans sa this ts oas ases tases coos bas wilas plos  od kisy and  anud a sas non  i@antal ald xe sa accokd oas say  bucas. hed assy hatg oon ted tass a: aouss  alians. ve and ir and lay los ace aod as th ad 6 qua, las sas blith . tos, ove this buy anse ?out, phusan as acooy a as ad saclauacusus, d sand am
# <SOR>os afod ond sastnd and oiant sats  ine and ans  ati and as autafd -as ousa0isakit yoousas coot othe sand y. "r  od  we sally yohs ls fywice a sa thand uans sasad gyoas olics g's les out asd ali(yd god ats es alins tos and has li u groind ans pes sas sw" aswisosed dei hot   nsalis sitame soy is oh mat wou  loos me i and poov
# <SOR>nas hows nd c2ott saly.tted ks sand koas and art sand lla was nd  is saf@ans is ac ansk k hois lis as as and a wes s a ddies cas  mitho. soo ast ysk, alwesjap$~ aloaszis d  g owpe yes alad is athe wid bi hous. vas fsazid  ictlo klks an lesover a yowo aso asd a d as  e nd satase e ok ha  feis e sis alas ous tilind sas and a
# gan batch:  139  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  139  is:  0.5
# discriminator training cost for gan batch  139  is:  0.693147
# generator training accuracy for gan batch  139  is:  1.0
# generator training cost for gan batch  139  is:  0.693142
# gan batch:  140
# generated during training batch  140 :
# <SOR>d hes sali a ove me as ca at asas ce  yed caly  a:buans and and eme ed ap odils od ay thay s and rksale ans, la akoau   zas ot bacet ols on sa oy edirvie rsad   wouserosaco hatsas, ol(sace ad as antant4 atskis walos foli blyot nd la a fing at , hais sal gos tr thelor say ve g wilins nd hofisond as ple  as ce le wfond as at
# <SOR>sau and au g alite kid ales rons, asaks live d 1nd alioud ais pkszis ved and wis the  oustsmesy -y kis safoiby as aced os ant oust as se asind alis ady as ri apwosad rie w*r coss sid. gome cons alud oved lasmas ws  kilis sass grous gou ons dius c). bind ake skzis ag osns aisks ac(le ; ud aminss phits and say ousaskd as a th
# <SOR>. isn1ind sacve - is  are stucoasme lay and g ot, ac i ous and ant oxhazid thay le f, os, lles g as id hased gh,   that as thi din ote is a lind he tho des upas, cis s9and te my yous d god as mus. sad sand and as woolallasand ass  mas shan statoo a ad ans mad ve yoi y, uziles ldadi mas. a th ilind k and whale mow agrinoy d
# <SOR>try ghons. w. swin ed and 2d ass pasas on as and and now sasd ye we way kite nos as asausazis.  les0 s las mis. yoous wis sousay ousid his   laloas saues9 aso ali ece and and a auas asaband ay  as a ad old g sand a was and sald and bodi; addtlis hog thand wasoos od douasts zad ad beswo he olast sat clesncwed as pas sau ere
# <SOR>mpesss clind ine, ad gh, asd ove as wis eta? whase sacawmesy sacs as thicke ace ure the cojsai md gha thand ans as ans ooatac asas es ans  sy. and a nd bask th agris as ad goind and cesy  fald cous hed a onloa yot ad was  ove casas be ale say as spighis acl oz, sand pl harous lyo and oas ancefed nd oustre sacout a hand o as
# gan batch:  140  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  140  is:  0.492188
# discriminator training cost for gan batch  140  is:  0.694491
# generator training accuracy for gan batch  140  is:  1.0
# generator training cost for gan batch  140  is:  0.693129
# gan batch:  141
# generated during training batch  141 :
# <SOR>thod gred zas as ya as cece oy os a as pos oud ous afis oied a lisa foy wajis sad liote yous. as as roas g lis sapes sai salous, is ad lis foooos sand ghlind jay ask as good anm bus as mas as d erous ouss la mand ad thy the me u unes lis lastaswiozis o at ansawisas a yooasad rd ad sas /salid as wisay ha s, id i-usplit u an
# <SOR>tois is as ad hfinsand ay os. pasa  sasnd yous youcas th, soins as cam  ntstlist tand ve soly be a ad hand  ans   os. haad thad zoosss ndipes is   come lo say. ha lis ssand  a lor lis. alid ag, ay _r as yous xoust ace sa2d us sand otand as, a  dkuss ap se zoas, gots and gtr gof a? and catled bu lis sato $s ace and ris h; os
# <SOR>ove and ansixthe . lr  and g sand as be zas co fis re sy wrijuasig 0past  ololle  ask aused sad nd nmmo ?d us lnsy asaly  wans say not h thask us asmou  mag  as thald  pisks as tos mask thes yooiis ase xe as as tsthe zals  adials otis as was a ived  me luy? an0y haved n es  axpcks os adis witld say ally as solid g aus.. ld
# <SOR>ejaus9 usa thay os od an sald as afis os sans wis lil ale  aais youd is bes allolanls ajay kim cyn ad  oo the haucas us le acesn  lis alpli{ pres ot, alig an chti  , zand gowatssatac). asas wfood  o swig zoalallos ande ad lala an oos, chaswk salis od  l^ and thed linus esis witre, is he thes goud ace and orskssa a fyooask a
# <SOR>ois ood e waxt y les wessok wfoove wh eid nd as and halianse soous god de hand po a ghay  osoe malind ns led and lan, us ale. sad and and sa gigfoole plis wod and s osthve as, o ac4 le toous. as asa asa sold sand hay loske as aces d fank es red yd axtaldthauste oydale oy ad tho, z e ad osn sa o atud  cou ad a cousnins u ove
# gan batch:  141  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  141  is:  0.5
# discriminator training cost for gan batch  141  is:  0.693147
# generator training accuracy for gan batch  141  is:  1.0
# generator training cost for gan batch  141  is:  0.693117
# gan batch:  142
# generated during training batch  142 :
# <SOR>i d cotsand sa ce lid as th yacwhis acand as os as es anind  wrice sk las ant is ofs weis, as custr ad ay anin a a alind the whed ce us ed jat pas zasdi[en gous youth a and ast. y. [ans s as ad atas his and mid lly lin tafud  soa losan ad  ass e  end sksad nd zalilobes yos lownd by 0oos wy layne reoves sad as ve allous risd
# <SOR>ile ousty psays, uly move zand  lotlalay andth and ou ad ad pled as uswaskmad sa sand les m osw y,   sokcand 9 a cas ove bhand  i@sas anota los ve ghats nd os sas thats sos hed  as ed akk pad and ag dtved h oustak as ad asasss athe acd wind and aicay o asess and  at mastse os as ous   soous e  be afd  asan lod nsat we a (ay
# <SOR>eve a as do lace ad pssasouths +val me a ouss  enty. say (s of ale pi jomes ze soove ty as, and thid nd rysas and ad tjuy tha  d ad ges cand sand d oufos ust gous wh oud ghatens ooame le tale bets bfsood  theskd o and pous as poos sy. les ans as a zas led ad me ssay wisqus say ay  w  liy and an sale and gooothas lusois wh a
# <SOR>mosthaund afi yowisas hat nd ld d and and ks noinisk fas pes sas + les andi  2in talas as ackand los fosed o ay ploud  oout whp the gout p oy. od es, jstlf sald ad a acmy o as oo say yse asd lud he as }acend ses us sar e tsaks sas o is netld as, w yout yd hed as  snws  d sas gres osan as ar o y, abons as os mon sa a ois o o
# <SOR>ouc on anst h to a and  ois {li ad sajt yog llins was ed as  oo swais acd p0s ved ootiswoyn soice ootr as k= a tod (, as thans cahaloy and asquas e sa nis esa8d ze guad dixou g had e wand b4soown alis  sansza yousis a and %iu o ad + ou  s ot thand li le as  es  hles he s n, pacey has at sant ofe e ?d he saf as, as s us kind
# gan batch:  142  has  64  real reviews and  64  artificial reviews.
# discriminator training accuracy for gan batch  142  is:  0.5
# discriminator training cost for gan batch  142  is:  0.693147
# generator training accuracy for gan batch  142  is:  1.0
# generator training cost for gan batch  142  is:  0.693107
# gan batch:  143
# generated during training batch  143 :
# <SOR>the as asf loos ad whye frthisad  pl o oalas this  ve lild as san chlid. asjay as adnd o tass, ass as le nos sans aprer asaus ca tstad kd and lo ld nd  owy swlis and as asca o as and e ass ans the esataliy as sasins is li sally thisacnd  sald d ousotsy be yout au  fos pe ous nd as ad ay  p  as oois lois k ol, and miste oy w
# <SOR>ad phe alilfs fove lify. pis on ans. liled baswrod sos it ad.  oec2usacoand fis asy p sis a he tres af as ulishanss th figegrced sad a shas as  ale as alisag zas this. as ve adi swas  ined gablouskd wis the las ante atos ffy oos cas oucs od icid les. los ele   wd an as  oind is his  hakd ad tolly p ous $ousand are ast ac7,
# <SOR>t4e oou sa and love a s, s an los  oves and sooaso yood ans onkilis tsatue asakd ns mis.  bas  co thand   sals pk ases lo tryzans. is sas os waceses and sos o taczis /fod  usat  ay and sand gosthe a alw| fas pros ple oos hns alit foves w sy oksithiais olos ga mas as, ged a ous asy sove sayece cfver an;  g and sa  alo hid as
# <SOR>ad d ansczizice a on les pousay ole .  sans  on o ook, cos son ad isant oay. y. be sas zand  a ald asit, le aty aderd  thas tho csthithi veck o asay ne kd sa a and s ac~ os  onwootis be mples aps ce a pes ad atres a ywe  as ineved thes lis ois cay olinted reas cas wis alos sas o a acgod hat wiles le nd and asks as ans th ot
# <SOR>ind uloustw audns aly fao nd he as blota ans me  lis o  waqut. apk ousad s wary frove sad fizins fes sally sand as  as the this sokd cans woy as. a a and we ;inauts us sat  as ou oas  asay sowk cas fmisir as as the s le nd a acove sasis as siand hedi. sact saucmattt yove ast and fooot oy tres, zas sad alsas yos he ouo ast a
# gan batch:  143  has  64  real reviews and  64  artificial reviews.

# %%
### UPDATED!!!
#save both RNNs for later use
save_command_1  = "gsutil cp -r " + trained_filename_real[0:trained_filename_real.rfind("/")] + " gs://w266_final_project_kk/defense_baseline/real/" + str(int(np.floor(time.time())))
save_command_2  = "gsutil cp -r " + trained_filename_artificial[0:trained_filename_artificial.rfind("/")] + " gs://w266_final_project_kk/defense_baseline/artificial/" + str(int(np.floor(time.time())))
#save_command_1  = "gsutil cp -r " + trained_filename_real[0:trained_filename_real.rfind("/")] + " gs://w266_final_project_kk/practice_run/defense_real/" + str(int(np.floor(time.time())))
#save_command_2  = "gsutil cp -r " + trained_filename_artificial[0:trained_filename_artificial.rfind("/")] + " gs://w266_final_project_kk/practice_run/defense_artificial/" + str(int(np.floor(time.time())))
os.system(save_command_1)
os.system(save_command_2)
### UPDATED!!!

#generate examples from each GAN out of curiosity
start_sampling = time.time()
generate_text(trained_filename, model_params, words_to_ids, ids_to_words)
#generate_text(trained_filename_artificial, model_params, words_to_ids, ids_to_words)
end_sampling = time.time()
print("character sampling took " + str(end_sampling-start_sampling) + " seconds")

#

#first feed the real reviews into each RNN and get the softmax probability of each character
#get the classification for real reviews by forming an average negative log-likelihood ratio for each review
start_scoring = time.time()
test_likelihoods_real_from_real = get_char_probs(trained_filename_real, model_params, test_ids_real[:1000])
test_likelihoods_real_from_artificial = get_char_probs(trained_filename_artificial, model_params, test_ids_real[:1000])
predictions_real = neg_log_lik_ratio(test_likelihoods_real_from_real, test_likelihoods_real_from_artificial)
#negative_log_lik_ratios = -1*(np.log(np.divide(test_likelihoods_real_from_real, test_likelihoods_real_from_artificial)))
#predictor = 

#next feed the generated reviews into each RNN and get the softmax probability of each character
#get the classification for generated reviews by forming an average negative log-likelihood ratio for each review
test_likelihoods_artificial_from_real = get_char_probs(trained_filename_real, model_params, test_ids_artificial[:1000])
test_likelihoods_artificial_from_artificial = get_char_probs(trained_filename_artificial, model_params, test_ids_artificial[:1000])
predictions_artificial = neg_log_lik_ratio(test_likelihoods_artificial_from_real, test_likelihoods_artificial_from_artificial)
end_scoring = time.time()
print("review scoring took " + str(end_scoring-start_scoring) + " seconds")

### UPDATED!!!
predictions_real = np.array(predictions_real)
predictions_artificial = np.array(predictions_artificial)
np.savetxt("predictions_real.csv", predictions_real, delimiter=",")
np.savetxt("predictions_artificial.csv", predictions_artificial, delimiter=",")
os.system("gsutil cp predictions_real.csv gs://w266_final_project_kk/defense_baseline/predictions_real/")
os.system("gsutil cp predictions_artificial.csv gs://w266_final_project_kk/defense_baseline/predictions_artificial/")
#os.system("gsutil cp predictions_real.csv gs://w266_final_project_kk/practice_run/defense_predictions_real/")
#os.system("gsutil cp predictions_artificial.csv gs://w266_final_project_kk/practice_run/defense_predictions_artificial/")
### UPDATED!!!
